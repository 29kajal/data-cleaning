# %%
#importing dataset
import pandas as pd
data=pd.read_csv("/content/food_coded.csv")
print(data)
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
missing_values=data.isnull()#identify missing values
print(missing_values)
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    False   False      False             False          True           False
# 1    False   False      False             False         False           False
# 2    False   False      False             False         False           False
# 3    False   False      False             False         False           False
# 4    False   False      False             False         False           False
# ..     ...     ...        ...               ...           ...             ...
# 120  False   False      False             False         False           False
# 121  False   False      False             False         False           False
# 122  False   False      False             False          True           False
# 123  False   False      False             False         False           False
# 124  False   False      False             False          True           False
#
# ...

# %%
#to calculate which column containing null values
data.isnull().sum()
# Out:
# GPA                  2
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day        19
#                     ..
# type_sports         21
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %%
data.describe()
# Out:
#            Gender   breakfast  calories_chicken  calories_day  calories_scone  \
# count  125.000000  125.000000        125.000000    106.000000      124.000000
# mean     1.392000    1.112000        577.320000      3.028302      505.241935
# std      0.490161    0.316636        131.214156      0.639308      230.840506
# min      1.000000    1.000000        265.000000      2.000000      315.000000
# 25%      1.000000    1.000000        430.000000      3.000000      420.000000
# 50%      1.000000    1.000000        610.000000      3.000000      420.000000
# 75%      2.000000    1.000000        720.000000      3.000000      420.000000
# max      2.000000    2.000000        720.000000      4.000000      980.000000
#
#           coffee  comfort_food_reasons_coded        cook  \
# count  125.00000                  106.000000  122.000000
# mean     1.75200                    2.698113    2.786885
# std      0.43359                    1.972042    1.038351
# ...

# %%
data.duplicated().sum()#check for duplicates
# Out:
# 0

# %%
median=data['calories_day'].median()#to find median of calories_day
print(median)
# Out:
# 3.0

# %%
data['calories_day']=data['calories_day'].fillna(median)#fill null values by median of calories_day
print(data)
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           3.0           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           3.0           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           3.0           315.0
#
# ...

# %%
data.isnull().sum()
# Out:
# GPA                  2
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day         0
#                     ..
# type_sports         21
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder_x=LabelEncoder()
data['type_sports']=label_encoder_x.fit_transform(data['type_sports'])#convert string value to integer
data
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           3.0           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           3.0           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           3.0           315.0
#
# ...

# %%
data['type_sports']=data['type_sports'].fillna(data['type_sports'].mode()[0])
data
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           3.0           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           3.0           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           3.0           315.0
#
# ...

# %%
data.isnull().sum()
# Out:
# GPA                 2
# Gender              0
# breakfast           0
# calories_chicken    0
# calories_day        0
#                    ..
# type_sports         0
# veggies_day         0
# vitamins            0
# waffle_calories     0
# weight              2
# Length: 61, dtype: int64

# %%
data['weight']=pd.to_numeric(data['weight'],errors='coerce')
data
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           3.0           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           3.0           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           3.0           315.0
#
# ...

# %%
data['weight']=data['weight'].fillna(data['weight'].median())
print(data)
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           3.0           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           3.0           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           3.0           315.0
#
# ...

# %%
data.isnull().sum()
# Out:
# GPA                 2
# Gender              0
# breakfast           0
# calories_chicken    0
# calories_day        0
#                    ..
# type_sports         0
# veggies_day         0
# vitamins            0
# waffle_calories     0
# weight              0
# Length: 61, dtype: int64

# %%
data['GPA']=pd.to_numeric(data['GPA'],errors='coerce')
data['GPA']=data['GPA'].fillna(value=data['GPA'].median())
data
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.400       2          1               430           3.0           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2    3.300       1          1               720           4.0           420.0
# 3    3.200       1          1               430           3.0           420.0
# 4    3.500       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120  3.500       1          1               610           4.0           420.0
# 121  3.000       1          1               265           2.0           315.0
# 122  3.882       1          1               720           3.0           420.0
# 123  3.000       2          1               720           4.0           420.0
# 124  3.900       1          1               430           3.0           315.0
#
# ...

# %%
missing_values=data.isnull().sum()
print(missing_values)#all the count of isnull value is 0 it means that data is clean
# Out:
# GPA                 0
# Gender              0
# breakfast           0
# calories_chicken    0
# calories_day        0
#                    ..
# type_sports         0
# veggies_day         0
# vitamins            0
# waffle_calories     0
# weight              0
# Length: 61, dtype: int64
